# %% [markdown]
# <a href="https://colab.research.google.com/github/joseeduardoparteka/AGRINHO-/blob/main/aula_phyton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Aula 1** 🏐 🛬 💫

# %%
aula = "IX"
print(f"{aula} aula de python")
# Out:
# IX aula de python

# %% [markdown]
# #**Aula 2** 🏰 🍂 🍀

# %%
livro_ficcao = 8
livro_n_ficcao = 10
livro_infantil = 6
pontos_rodrigo = livro_ficcao + livro_n_ficcao + livro_infantil
print(f"Os pontos totais do Rodrigo são {pontos_rodrigo}")
# Out:
# Os pontos totais do Rodrigo são 24

# %%
livro_ficcao = 8
livro_n_ficcao = 10
livro_infantil = 6
pontos_rodrigo = livro_ficcao + livro_n_ficcao + livro_infantil
pontos_ana = 2 * livro_ficcao + 6 * livro_infantil
pontos_totais = pontos_rodrigo + pontos_ana

print(f"Os pontos totais do Rodrigo são {pontos_rodrigo}")
print(f"Os pontos totais da Ana são {pontos_ana}")
print(f"Os pontos totais do Rodrigo e da Ana são {pontos_totais}")
# Out:
# Os pontos totais do Rodrigo são 24
# Os pontos totais da Ana são 52
# Os pontos totais do Rodrigo e da Ana são 76

# %% [markdown]
# #**Aula 3: Tabuada** 📸 🎲 🌠

# %%
def tabuada(numero):
    for contador in range(1, 11):  # Gera números de 1 a 10
        print(f"{numero} x {contador} = {numero * contador}")
numero = int(input("Digite um número para ver sua tabuada: "))
tabuada(numero)
# Out:
# Digite um número para ver sua tabuada: 5
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %% [markdown]
# #**Aula 4: IMC** ⭐ 🦋 💘

# %%
peso = float(input("Digite seu peso (em kg): "))
altura = float(input("Digite sua altura (em metros): "))

imc = peso / (altura ** 2)

print(f"\nSeu IMC é: {imc:.2f}")
if imc < 18.5:
    print("Você está abaixo do peso.")
elif 18.5 <= imc < 25:
    print("Você está no peso ideal.")
elif 25 <= imc < 30:
    print("Você está com sobrepeso.")
else:
    print("Você está acima do peso.")
# Out:
# Digite seu peso (em kg): 56
# Digite sua altura (em metros): 1.65
#
# Seu IMC é: 20.57
# Você está no peso ideal.

# %% [markdown]
# #**Aula 5: chatbot** 📟 🤖 🕜

# %%
print("olá, eu sou seu assistente virtual!")
nome = input("poderia me dizer seu nome? ")
print(f"olá {nome}, em que posso ajudar?")
assunto = input("qual o assunto que deseja tratar? python, javascript ou scratch: ").lower()
if assunto == "python":
 print(f"que legal {nome}, vamos falar sobre python. \n Python é uma linguagem simples, poderosa e versátil para programação.")
elif assunto == "javascript":
 print(f"que legal {nome}, vamos falar sobre javascript. \n JavaScript é uma linguagem versátil usada para programação web interativa.")
elif assunto == "scratch":
 print(f"que legal {nome}, vamos falar sobre scratch. \n Scratch é uma linguagem visual usada para aprender programação de forma divertida.")
else:
  print(f"que pena {nome}, não tenho conteúdo sobre esse assunto :c")
# Out:
# olá, eu sou seu assistente virtual!
# poderia me dizer seu nome? bianca
# olá bianca, em que posso ajudar?
# qual o assunto que deseja tratar? python, javascript ou scratch: scratch
# que legal bianca, vamos falar sobre scratch.
#  Scratch é uma linguagem visual usada para aprender programação de forma divertida.

# %% [markdown]
# #**Aula 6: listas** 💙 🐦 🧬

# %%
import random
dicas = [
"🌟 Acredite em você!",
"💪 Você é mais forte do que imagina.",
"🚀 Vá além dos seus limites!",
"🌈 Cada dia é uma nova chance.",
"🔥 Transforme sonhos em ação!",
"☀️ Escolha brilhar, mesmo nos dias nublados.",
"🌻 Siga firme, o melhor ainda está por vir.",
"🌊 Continue, mesmo que devagar.",
"🦋 Mude, evolua, floresça.",
"🏆 A vitória começa com a coragem de tentar.",
"🌠 Nunca desista dos seus sonhos.",
"💫 Pequenos passos também levam longe.",
"🌻 Espalhe coisas boas por onde passar.",
"🔑 Acredite no processo, tudo tem seu tempo.",
"🌞 Sorria, a vida fica mais leve assim.",
"🌹 Você é capaz de tudo que acredita.",
"🌍 Faça o seu melhor e o universo faz o resto.",

]
while True:
  pedido = input("Digite 'dica' para receber uma dica ou 'sair' para encerrar \n ").lower()

  if pedido == "dica":
    dica = random.choice(dicas) # escolhe uma dica aleatória sair
    print(f"dica: {dica} \n")
  elif pedido == "sair":
    print("até a próxima! \n")
    break
  else:
    print("comando inválido. Tente novamente. \n")
    break
# Out:
# Digite 'dica' para receber uma dica ou 'sair' para encerrar
#  dica
# dica: 🌞 Sorria, a vida fica mais leve assim.
#
# Digite 'dica' para receber uma dica ou 'sair' para encerrar
#  dica
# dica: 🦋 Mude, evolua, floresça.
#
# Digite 'dica' para receber uma dica ou 'sair' para encerrar
#  shnk
# comando inválido. Tente novamente.
